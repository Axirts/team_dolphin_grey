# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/Claims_Reimbursement_to_Health_Care_Providers_and_Facilities_for_Testing__Treatment__and_Vaccine_Administration__of_the_Uninsured.csv')

# %%
df.describe()
# Out:
#                Provider Name  State     City Claims Paid for Testing  \
# count                  36845  36845    36845                   36845
# unique                 17201     55     6135                   12598
# top     PRIVIA MEDICAL GROUP     TX  HOUSTON                 $   - 0
# freq                     101   3761      454                   14618
#
#        Claims Paid for Treatment Claims Paid for Vaccine  \
# count                      36845                   36845
# unique                     13515                    4583
# top                      $   - 0                 $   - 0
# freq                        9071                   28544
#
#                 Georeferenced Column
# count                          36825
# unique                          8157
# top     POINT (-95.369506 29.760803)
# freq                             452

# %%
df.head(3)
# Out:
#             Provider Name State        City Claims Paid for Testing  \
# 0  TOMBIGBEE HEALTHCARE A    AL  DEMPOPOLIS                 $   564
# 1   ARKANSAS HEALTH GROUP    AR       BEEBE                 $   245
# 2                CARELOCK    AZ    PRESCOTT                 $   181
#
#   Claims Paid for Treatment Claims Paid for Vaccine  \
# 0                   $   234                 $   - 0
# 1                    $   49                 $   - 0
# 2                   $   - 0                 $   - 0
#
#             Georeferenced Column
# 0                            NaN
# 1   POINT (-91.881745 35.075503)
# 2  POINT (-112.470124 34.541445)

# %%
df['City'].value_counts()
# Out:
# HOUSTON           454
# CHICAGO           321
# BROOKLYN          256
# NEW YORK          209
# PHOENIX           201
#                  ...
# BRADSHAW            1
# KEY BISCAYNE        1
# PERKINS             1
# SLINGER             1
# WILLISTON PARK      1
# Name: City, Length: 6135, dtype: int64

# %%
df.groupby(by='State').describe()
# Out:
#       Provider Name                                      City         \
#               count unique                     top freq count unique
# State
# AK               72     60     EXPRESS CARE AK LLC    4    72     24
# AL              660    427    AMERICAN FAMILY CARE   30   660    166
# AR              501    285   ARKANSAS HEALTH GROUP   22   501    154
# AZ              743    373               AKDHC LLC   36   743     75
# CA             2464   1324  6 PALO ALTO MEDICAL FO   51  2464    458
# CO              503    243  UCHEALTH MEDICAL GROUP   37   503    100
# CT              336    155  NORTHEAST MEDICAL GROU   36   336     90
# DC               98     57       UNITY HEALTH CARE    7    98      1
# DE              101     62  CHRISTIANA CARE HEALTH   15   101     23
# FL             2301   1323  MORTON PLANT MEASE PRI   47  2301    284
# GA             1433    829  WELLSTAR MARIETTA INTE   36  1433    256
# ...

# %%
df[df['City'] == 'SAN JOSE']

# %%
df.describe()
# Out:
#                Provider Name  State     City Claims Paid for Testing  \
# count                  36845  36845    36845                   36845
# unique                 17201     55     6135                   12598
# top     PRIVIA MEDICAL GROUP     TX  HOUSTON                 $   - 0
# freq                     101   3761      454                   14618
#
#        Claims Paid for Treatment Claims Paid for Vaccine  \
# count                      36845                   36845
# unique                     13515                    4583
# top                      $   - 0                 $   - 0
# freq                        9071                   28544
#
#                 Georeferenced Column
# count                          36825
# unique                          8157
# top     POINT (-95.369506 29.760803)
# freq                             452

# %%
df

# %%
df.sort_values(by='Claims Paid for Testing', ascending=False)

# %%
df.sort_values(by='Claims Paid for Treatment', ascending=False)
